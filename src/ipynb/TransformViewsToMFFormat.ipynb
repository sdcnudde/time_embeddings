# %%
import os
import pandas
count_line = 0

# %%
views_df = pandas.read_csv('~/Downloads/customer_product_date.csv', sep='\t', header=None, names = ['cid', 'pid', 'dates'])

# %%
views_df = views_df[['cid', 'pid']]

# %%
views_df
# Out:
#                 cid      pid
# 0          69112500    52840
# 2         103311350    52840
# 4          13341550    52840
# 6           2077600    52840
# 8         110704650    59681
# 12         56070450    59700
# 17         76526400    79225
# 18          6516850    85441
# 20         39884400    85441
# 22         72081750    85441
# 24          7436850    85441
# 26         22563750    85441
# 28         47392800    85441
# 30         57574800    85441
# 32         53653350    85441
# 34         59134050    85441
# 36         22437450    85441
# 38         22437450    85441
# 40         67546200    85441
# 42         32309250    85441
# 44        108128950    85441
# 46         44923350    85441
# 48          6927900    85441
# 50         49771650    97242
# 52         49771650    97242
# 54         49771650    97242
# 56         14441550    97242
# 58         21174150    97242
# 60         10783850    97242
# 62         28016550    97242
# ...             ...      ...
# ...

# %%
views_gb = views_df.groupby(['cid', 'pid']).size().reset_index(name="cnt")

# %%
views_gb
# Out:
#                 cid      pid  cnt
# 0                50  4547366    1
# 1                50  4566011    1
# 2                50  4807130    1
# 3                50  4964126    1
# 4                50  5015929    4
# 5                50  5045958    4
# 6                50  5110931    1
# 7                50  5111124    1
# 8                50  5163444    1
# 9                50  5164030    1
# 10               50  5168576    1
# 11               50  5224063    1
# 12               50  5243818    1
# 13               50  5246078    1
# 14               50  5347847    1
# 15               50  5348227    1
# 16               50  5378611    1
# 17               50  5441969    1
# 18               50  5452128    1
# 19               50  5540743    1
# 20               50  5552438    1
# 21               50  5552630    1
# 22               50  5613057    1
# 23               50  5625515    1
# 24               50  5689317    1
# 25               50  5758061    1
# ...

# %%
views_gb.to_csv('~/Documents/customer_product_rating.csv', header=None)
